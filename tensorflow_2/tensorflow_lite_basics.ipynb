# %%
import tensorflow as tf

# %%
converter = tf.lite.TFLiteConverter.from_saved_model("./saved_model_dir/converted_model.tflite")

tflite_model = converter.convert()
tflite_quant_model = converter.convert()
open("converted_model.tflite", "wb").write(tflite_model)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 converter = tf.lite.TFLiteConverter.from_saved_model("./saved_model_dir/converted_model.tflite")
#       2 tflite_model = converter.convert()
#       3 open("converted_model.tflite", "wb").write(tflite_model)
#
# File ~/meine_projects/USAII/tensorflow_2/venv/lib/python3.11/site-packages/tensorflow/lite/python/lite.py:2229, in TFLiteConverterV2.from_saved_model(cls, saved_model_dir, signature_keys, tags)
#    2226   tags = set([_tag_constants.SERVING])
#    2228 with context.eager_mode():
# -> 2229   saved_model = _load(saved_model_dir, tags)
#    2230 if not signature_keys:
#    2231   signature_keys = list(saved_model.signatures.keys())
#
# File ~/meine_projects/USAII/tensorflow_2/venv/lib/python3.11/site-packages/tensorflow/python/saved_model/load.py:912, in load(export_dir, tags, options)
#     910 if isinstance(export_dir, os.PathLike):
#     911   export_dir = os.fspath(export_dir)
# --> 912 result = load_partial(export_dir, None, tags, options)["root"]
#     913 return result
#
# File ~/meine_projects/USAII/tensorflow_2/venv/lib/python3.11/site-packages/tensorflow/python/saved_model/load.py:1016, in load_partial(export_dir, filters, tags, options)
#    1011 if tags is not None and not isinstance(tags, set):
#    1012   # Supports e.g. tags=SERVING and tags=[SERVING]. Sets aren't considered
#    1013   # sequences for nest.flatten, so we put those through as-is.
#    1014   tags = nest.flatten(tags)
#    1015 saved_model_proto, debug_info = (
# -> 1016     loader_impl.parse_saved_model_with_debug_info(export_dir))
#    1018 loader = None
#    1019 if (len(saved_model_proto.meta_graphs) == 1 and
#    1020     saved_model_proto.meta_graphs[0].HasField("object_graph_def")):
#
# File ~/meine_projects/USAII/tensorflow_2/venv/lib/python3.11/site-packages/tensorflow/python/saved_model/loader_impl.py:59, in parse_saved_model_with_debug_info(export_dir)
#      46 def parse_saved_model_with_debug_info(export_dir):
#      47   """Reads the savedmodel as well as the graph debug info.
#      48
#      49   Args:
#    (...)
#      57     parsed. Missing graph debug info file is fine.
#      58   """
# ---> 59   saved_model = parse_saved_model(export_dir)
#      61   debug_info_path = file_io.join(
#      62       path_helpers.get_debug_dir(export_dir),
#      63       constants.DEBUG_INFO_FILENAME_PB)
#      64   debug_info = graph_debug_info_pb2.GraphDebugInfo()
#
# File ~/meine_projects/USAII/tensorflow_2/venv/lib/python3.11/site-packages/tensorflow/python/saved_model/loader_impl.py:119, in parse_saved_model(export_dir)
#     117     raise IOError(f"Cannot parse file {path_to_pbtxt}: {str(e)}.") from e
#     118 else:
# --> 119   raise IOError(
#     120       f"SavedModel file does not exist at: {export_dir}{os.path.sep}"
#     121       f"{{{constants.SAVED_MODEL_FILENAME_PBTXT}|"
#     122       f"{constants.SAVED_MODEL_FILENAME_PB}}}")
#     123 return saved_model
#
# OSError: SavedModel file does not exist at: ./saved_model_dir/converted_model.tflite/{saved_model.pbtxt|saved_model.pb}
