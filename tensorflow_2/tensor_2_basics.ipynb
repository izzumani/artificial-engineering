# %% [markdown]
# Keras is another popularly used deep learning library. It was developed by François Chollet at Google. It is well known for its fast prototyping, and it makes model building simple. It is a high-level library, meaning that it does not perform any lowlevel operations on its own, such as convolution. It uses a backend engine for doing that, such as TensorFlow. The Keras API is available in tf.keras, and TensorFlow
# 2.0 uses it as the primary API.

# %% [markdown]
# Building a model in Keras involves four important steps:
# 1. Defining the model
# 2. Compiling the model
# 3. Fitting the model
# 4. Evaluating the model

# %% [markdown]
# Defining the model
# The first step is defining the model. Keras provides two different APIs to define the
# model:
# • The sequential API
# • The functional API

# %% [markdown]
# Defining a sequential model
# In a sequential model, we stack each layer, one above another:

# %%
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# %%
model = Sequential()

# %% [markdown]
# define the first layer
#
# Dense implies a fully connected layer, input_dim implies the dimension of our input, and activation specifies the activation function that we use. We can stack up as many layers as we want, one above another.

# %%
model.add(Dense(13, input_dim=7, activation='relu'))

# %% [markdown]
# Define the next layer with the relu activation

# %%
model.add(Dense(7, activation='relu'))

# %% [markdown]
# Define the output layer with the sigmoid activation function

# %%
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# Defining a functional model
# A functional model provides more flexibility than a sequential model. For instance, in a functional model, we can easily connect any layer to another layer, whereas, in a sequential model, each layer is in a stack, one above another. A functional model comes in handy when creating complex models, such as directed acyclic graphs, models with multiple input values, multiple output values, and shared layers.

# %% [markdown]
# from define the input dimensions:

# %%
input = tf.keras.Input(shape=(2,))

# %% [markdown]
# we’ll define our first fully connected layer with 10 neurons and relu activation, using the Dense class

# %%
layer1 = Dense(10, activation='relu')

# %% [markdown]
# We defined layer1, but where is the input to layer1 coming from? We need to specify the input to layer1 in a bracket notation at the end

# %%
layer1 = Dense(10, activation='relu')(input)

# %% [markdown]
# We define the next layer, layer2, with 13 neurons and relu activation. The input to layer2 comes from layer1, so that is added in the bracket at the end,

# %%
layer2 = Dense(10, activation='relu')(layer1)

# %% [markdown]
# After defining all of the layers, we define the model using a Model class, where we need to specify inputs and outputs, as follows

# %%
output = Dense(1, activation='sigmoid')(layer2)
model = tf.keras.Model(inputs=input, outputs=output)

# %% [markdown]
# Compiling the model

# %% [markdown]
# We define three parameters when compiling the model:
# • The optimizer parameter: This defines the optimization algorithm we want to use; for example, the gradient descent.
# • The loss parameter: This is the objective function that we are trying to minimize; for example, the mean squared error or cross-entropy loss.
# • The metrics parameter: This is the metric through which we want to assess the model’s performance; for example, accuracy. We can also specify more than one metric.

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %% [markdown]
# Training the model
# Training the model can be done using the fit function. We specify our features, x; labels, y; the number of epochs we want to train the model for; and batch_size, as follows:
# ```python
# model.fit(x=data, y=labels, epochs=100, batch_size=10)
# ```

# %% [markdown]
# Evaluating the model
# ```python
# model.evaluate(x=data_test,y=labels_test)
# ```
#
# We can also evaluate the model on the same train set, and that will help us to understand the training accuracy
# ```python
# model.evaluate(x=data,y=labels)
# ```

# %% [markdown]
# MNIST digit classification using TensorFlow 2.0

# %%
mnist = tf.keras.datasets.mnist

# %% [markdown]
# Create a training set and a test set with the following code:

# %%
(x_train,y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Normalize the train and test sets by dividing the values of x by the maximum value of x; that is, 255.0:

# %%
x_train, x_test = tf.cast(x_train/255.0, tf.float32), tf.cast(x_test/255.0, tf.float32)
# Out:
# 2024-09-26 09:36:50.695351: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 376320000 exceeds 10% of free system memory.
# 2024-09-26 09:37:02.116587: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 188160000 exceeds 10% of free system memory.
# 2024-09-26 09:37:07.618109: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 62720000 exceeds 10% of free system memory.

# %%
y_train, y_test = tf.cast(y_train,tf.int64),tf.cast(y_test,tf.int64)

# %% [markdown]
# Define the sequential model as follows:

# %%
model = tf.keras.models.Sequential()

# %% [markdown]
# Now, let’s add layers to the model. We use a three-layer network with the ReLU function in the hidden layer and softmax in the final layer:

# %%
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256, activation="relu"))
model.add(tf.keras.layers.Dense(128, activation="relu"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

# %%
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, batch_size=32, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.7362 - loss: 1.0112
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9139 - loss: 0.2985
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9325 - loss: 0.2384
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9406 - loss: 0.2072
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9475 - loss: 0.1827
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9557 - loss: 0.1563
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9592 - loss: 0.1397
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9650 - loss: 0.1255
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9665 - loss: 0.1179
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9713 - loss: 0.1040

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9613 - loss: 0.1252
# [0.10909592360258102, 0.9667999744415283]
